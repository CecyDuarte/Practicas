# %%
indices<-read.csv(file="indices_bursatiles_retornos _2020.csv", header=TRUE, sep=",", dec=".")

# %%
plot.ts(indices)
# Out:
# plot without title

# %%
indices_tras=t(indices)
indices_tras<-indices_tras[2:7,]
indices_tras
# Out:
#       [,1]      [,2]      [,3]      [,4]      [,5]      [,6]      [,7]
# FCHI    0.52301  -0.02062   0.30971   0.19132  -0.09007   0.06260  -0.13716
# GDAXI  -0.92524   0.75769   0.70328   1.30435  -0.08711  -0.19911  -0.17993
# IBEX   -0.12178  -0.22002   0.12102  -0.10015  -0.08562  -0.47430  -0.17437
# NDX     1.58093  -0.02339   0.74239   0.86315  -0.25607   0.74200   0.02490
# N225  -1.92812   1.58557  -1.58600   2.27985   0.46523   0.72939  -0.45301
# STI   -0.11115   0.89691  -0.06068   0.04898   0.26048   0.44710  -0.41547
#       [,8]      [,9]      [,10]     [,11] [,12]     [,13]     [,14]
# FCHI    0.10636   1.01635  -0.90116 ...    -0.08180   3.36447   0.64892
# GDAXI  -0.02137   0.71748   0.21963 ...     0.21165   3.09897   0.47058
# IBEX    0.63718   1.13018  -0.72567 ...    -1.11889   1.64823  -0.64637
# NDX     0.98378   0.53261  -0.07743 ...     1.91213   0.84798  -1.20624
# N225   0.06918   0.45078  -0.73770  ...   -1.33827   3.09849  -1.15322
# ...

# %% [markdown]
# **Aquí tuve que cambiar la matriz para que fuera un dataframe de datos númericos porque me marcaba error al quererlo ejecutar**

# %%
mode(indices_tras) = "numeric"
data.frame(indices_tras)
# Out:
#       X1       X2       X3       X4       X5       X6       X7       X8
# FCHI   0.52301 -0.02062  0.30971  0.19132 -0.09007  0.06260 -0.13716  0.10636
# GDAXI -0.92524  0.75769  0.70328  1.30435 -0.08711 -0.19911 -0.17993 -0.02137
# IBEX  -0.12178 -0.22002  0.12102 -0.10015 -0.08562 -0.47430 -0.17437  0.63718
# NDX    1.58093 -0.02339  0.74239  0.86315 -0.25607  0.74200  0.02490  0.98378
# N225  -1.92812  1.58557 -1.58600  2.27985  0.46523  0.72939 -0.45301  0.06918
# STI   -0.11115  0.89691 -0.06068  0.04898  0.26048  0.44710 -0.41547  0.64331
#       X9      X10      ... X63      X64     X65      X66      X67      X68
# FCHI  1.01635 -0.90116 ... -0.08180 3.36447  0.64892 -3.84572  1.23934  0.88461
# GDAXI 0.71748  0.21963 ...  0.21165 3.09897  0.47058 -4.07259  1.59869  0.94378
# IBEX  1.13018 -0.72567 ... -1.11889 1.64823 -0.64637 -2.92007  1.27148  0.39655
# NDX   0.53261 -0.07743 ...  1.91213 0.84798 -1.20624 -3.77767  3.06616 -0.26742
# ...

# %%
library(FactoMineR)

# %% [markdown]
# **Obtención de ACP de índices traspuestos**

# %%
acp_ind_tras<-PCA(indices_tras) #Aquí no pongo los gráficos porque loharé de manera individual
acp_ind_tras
# Out:
# **Results for the Principal Component Analysis (PCA)**
# The analysis was performed on 6 individuals, described by 72 variables
# *The results are available in the following objects:
#
#    name               description
# 1  "$eig"             "eigenvalues"
# 2  "$var"             "results for the variables"
# 3  "$var$coord"       "coord. for the variables"
# 4  "$var$cor"         "correlations variables - dimensions"
# 5  "$var$cos2"        "cos2 for the variables"
# 6  "$var$contrib"     "contributions of the variables"
# 7  "$ind"             "results for the individuals"
# 8  "$ind$coord"       "coord. for the individuals"
# 9  "$ind$cos2"        "cos2 for the individuals"
# 10 "$ind$contrib"     "contributions of the individuals"
# 11 "$call"            "summary statistics"
# 12 "$call$centre"     "mean of the variables"
# 13 "$call$ecart.type" "standard error of the variables"
# 14 "$call$row.w"      "weights for the individuals"
# ...

# %%
plot(acp_ind_tras, choix="ind") #el argumento choix, nos ayuda a indicar que lo quiero de manera individual
# Out:
# plot without title

# %%
plot(acp_ind_tras, choix="var") #el argumento choix, nos ayuda a indicar que lo quiero por variable, aunque no se aprecia muy bien
# Out:
# plot without title
